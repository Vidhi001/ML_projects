# %% [markdown]
# #                    ****** PIMA INDIAN DIABETES(MINOR PROJECT)******

# %% [markdown]
# 1.Import the dataset.

# %%
import pandas as pd
df = pd.read_csv("data/datasetsdiabetes.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-0b7e6d30b351> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("data/datasetsdiabetes.csv")
#       3 df.head()
#
# c:\Users\DELL\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
y = df["Outcome"]
X = df.drop("Outcome",axis=1)

# %% [markdown]
# 2.Data quality check:<br>
#     &emsp;&emsp;a.Check if null values are present. If there are, fill those null values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# 3.	Exploratory Data Analysis:<br>
# &emsp;&emsp;a.	Univariate Analysis:<br>
# &emsp;&emsp;&emsp;&emsp;i.	Draw  histograms for all the columns in the dataset .

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.gca()
df.hist(ax=ax,color='green')
plt.show()

# %% [markdown]
# ;
# p&emsp;&emsp;b.	Bivariate analysis:<br>
# &emsp;&emsp;&emsp;&emsp;i.	Draw a minimum of 5 scatter plots

# %%
for i in range(6):
    a = X.sample(n=1,axis=1,replace=True)
    b = X.sample(n=1,axis=1,replace=True)
    plt.scatter(a,b,color='green')
    plt.xlabel(a.columns[0])
    plt.ylabel(b.columns[0])
    plt.show()

# %% [markdown]
# 4.	Modelling:<br>
# &emsp;&emsp;a.	Split the dataset using “train-test-split” function.<br>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,stratify=y,random_state=20)

# %% [markdown]
# b. Apply KNN classification on “Outcome” column of the dataset. Select the appropriate features

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %% [markdown]
# c. Apply Decision Tree Classifier on “Outcome” column of the dataset. Select the appropriate features

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
#  d. Check score on the test set

# %%
knn.score(X_test,y_test)
# Out:
# 0.7395833333333334

# %%
model.score(X_test,y_test)
# Out:
# 0.703125

# %% [markdown]
# e. Predict on new data set (minimum 1 row).

# %%
dict1 = {0:[5],1:[150],2:[70],3:[35],4:[120],5:[22.2],6:[2.026],7:[32]}
data1 = pd.DataFrame(dict1)

# %%
knn.predict(data1)
# Out:
# array([1], dtype=int64)

# %%
model.predict(data1)
# Out:
# array([1], dtype=int64)
